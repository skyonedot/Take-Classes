# %%
import numpy as np
import pandas as pd
np.random.seed(2)
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.randint(1,3,100)
v = np.random.rand(100)/10

# %%
from sklearn.datasets import make_blobs
data_new,label = make_blobs(n_samples=200,n_features=2,centers=3)
plt.scatter(data_new[:,0],data_new[:,1],c=label)

# %%
pd.DataFrame(np.hstack((data_new,label.reshape(len(label),1)))).to_csv('Day22-homework.csv')

# %%
def data_generate():
    x = np.random.rand(100)
    y = np.random.rand(100)
    z = np.random.randint(1,3,100)
    return (np.hstack((x.reshape(100,1),y.reshape(100,1),z.reshape(100,1))))

# %%
def plot_data():
    data = data_generate()
    plt.scatter(data[:,0],data[:,1],c=data[:,2])    
    plt.show()

# %%
plot_data()

# %%
data = data_generate()

# %%
plt.scatter(data[:,0],data[:,1],c=data[:,2])

# %%
x1 = np.random.rand(100)

# %%
x
# Out:
# array([0.4359949 , 0.02592623, 0.54966248, 0.43532239, 0.4203678 ,
#        0.33033482, 0.20464863, 0.61927097, 0.29965467, 0.26682728,
#        0.62113383, 0.52914209, 0.13457995, 0.51357812, 0.18443987,
#        0.78533515, 0.85397529, 0.49423684, 0.84656149, 0.07964548,
#        0.50524609, 0.0652865 , 0.42812233, 0.09653092, 0.12715997,
#        0.59674531, 0.226012  , 0.10694568, 0.22030621, 0.34982629,
#        0.46778748, 0.20174323, 0.64040673, 0.48306984, 0.50523672,
#        0.38689265, 0.79363745, 0.58000418, 0.1622986 , 0.70075235,
#        0.96455108, 0.50000836, 0.88952006, 0.34161365, 0.56714413,
#        0.42754596, 0.43674726, 0.77655918, 0.53560417, 0.95374223,
#        0.54420816, 0.08209492, 0.3663424 , 0.8508505 , 0.40627504,
#        0.02720237, 0.24717724, 0.06714437, 0.99385201, 0.97058031,
#        0.80025835, 0.60181712, 0.76495986, 0.16922545, 0.29302323,
#        0.52406688, 0.35662428, 0.04567897, 0.98315345, 0.44135492,
# ...

# %%
x1
# Out:
# array([0.52316933, 0.3250568 , 0.92979042, 0.84820141, 0.84112295,
#        0.95428864, 0.00248243, 0.4921191 , 0.93791312, 0.13442676,
#        0.24499414, 0.50506192, 0.67842151, 0.33275996, 0.30636467,
#        0.77579791, 0.03285394, 0.78579786, 0.42854028, 0.62900946,
#        0.70550302, 0.09846863, 0.90384616, 0.82231247, 0.37538144,
#        0.19479433, 0.06280544, 0.30860893, 0.71319196, 0.81318172,
#        0.3265883 , 0.22028989, 0.32739418, 0.96436684, 0.0960907 ,
#        0.16218345, 0.69423912, 0.1397635 , 0.26662589, 0.80317587,
#        0.30061178, 0.59701655, 0.57281229, 0.26544347, 0.24873429,
#        0.28967549, 0.87594007, 0.01875815, 0.09163641, 0.34120996,
#        0.22030166, 0.5628574 , 0.53946109, 0.495362  , 0.30075307,
#        0.51144873, 0.78622852, 0.81250558, 0.53284089, 0.80633521,
#        0.03427548, 0.15406612, 0.74818503, 0.3848699 , 0.31789849,
#        0.57200881, 0.37242052, 0.90952991, 0.38697123, 0.8362492 ,
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x,x1)
plt.show()
