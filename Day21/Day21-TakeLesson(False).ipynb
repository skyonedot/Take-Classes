# %%
import numpy as np
import pandas as pd
np.random.seed(2)
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.randint(1,3,100)
v = np.random.rand(100)/10

# %%
##

# %%
data = pd.DataFrame(np.hstack((x.reshape(100,1),y.reshape(100,1),z.reshape(100,1))))
data.columns = ['x','y','label']

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show()

# %%
pd.Series(z).value_counts()
# Out:
# 1    54
# 2    46
# dtype: int64

# %%
colors = ['red','blue']

# %%
for i in range(2):
    x1 = data.loc[data['label']==i+1]['x']
    y1 = data.loc[data['label']==i+1]['y']
    plt.scatter(x1,y1,c = colors[i])

# %%
d = np.hstack((x.reshape(100,1),y.reshape(100,1)))
plt.scatter(d[:,0],d[:,1],c=z)

# %%
from sklearn.datasets import make_blobs
data_new,label = make_blobs(n_samples=200,n_features=2,centers=5)
plt.scatter(data_new[:,0],data_new[:,1],c=label)

# %%
data_new.shape
# Out:
# (200, 2)

# %%
da

# %%
label
# Out:
# array([0, 4, 0, 4, 2, 0, 1, 4, 0, 4, 2, 2, 3, 3, 1, 1, 3, 1, 3, 3, 1, 3,
#        3, 2, 3, 2, 4, 2, 0, 1, 1, 4, 4, 4, 3, 1, 4, 0, 3, 4, 3, 4, 4, 2,
#        1, 1, 4, 4, 3, 1, 2, 0, 1, 1, 4, 0, 1, 3, 2, 0, 4, 1, 3, 0, 4, 2,
#        4, 0, 1, 3, 3, 4, 1, 4, 2, 3, 1, 4, 4, 4, 4, 0, 1, 2, 1, 2, 0, 2,
#        1, 1, 3, 4, 3, 4, 3, 1, 0, 4, 2, 3, 0, 0, 3, 0, 2, 3, 0, 0, 2, 2,
#        2, 2, 4, 3, 3, 1, 1, 0, 2, 0, 2, 4, 2, 2, 2, 3, 2, 2, 0, 3, 3, 3,
#        2, 4, 3, 0, 2, 0, 2, 1, 3, 1, 0, 1, 2, 0, 3, 3, 3, 4, 4, 0, 1, 0,
#        1, 2, 0, 0, 2, 2, 1, 4, 3, 0, 1, 1, 4, 0, 0, 1, 0, 2, 0, 2, 3, 4,
#        3, 0, 4, 4, 1, 4, 3, 1, 1, 3, 2, 2, 4, 0, 1, 2, 2, 3, 4, 0, 0, 1,
#        1, 0])

# %%
data
# Out:
#            x         y  label
# 0   0.849831  0.257292    2.0
# 1   0.380854  0.697138    1.0
# 2   0.213966  0.423574    1.0
# 3   0.298558  0.392964    2.0
# 4   0.824130  0.736161    1.0
# ..       ...       ...    ...
# 95  0.388181  0.797142    2.0
# 96  0.631083  0.520189    2.0
# 97  0.446011  0.316468    1.0
# 98  0.896642  0.199360    1.0
# 99  0.496131  0.572154    2.0
#
# [100 rows x 3 columns]

# %%
##先生成数据

## 后画图
# 自己尝试着画
##再计算哪一个最先到达
##到x轴 到y轴?

##后面讲分类 和 正则表达式
